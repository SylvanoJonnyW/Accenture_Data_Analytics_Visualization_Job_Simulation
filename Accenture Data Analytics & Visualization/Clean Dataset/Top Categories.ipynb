# %%
import pandas as pd

# %%
df = pd.read_csv('Merge_Table.csv', delimiter=';')

df.head()
# Out:
#               Datetime                             ContentID ContentType  \
# 0  2020-11-07 09:43:50  97522e57-d9ab-4bd6-97bf-c24d952602d2       Photo
# 1  2021-06-17 12:22:51  97522e57-d9ab-4bd6-97bf-c24d952602d2       Photo
# 2  2021-04-18 05:13:58  97522e57-d9ab-4bd6-97bf-c24d952602d2       Photo
# 3  2021-01-06 19:13:01  97522e57-d9ab-4bd6-97bf-c24d952602d2       Photo
# 4  2020-08-23 12:25:58  97522e57-d9ab-4bd6-97bf-c24d952602d2       Photo
#
#    Category    Reaction  Score  \
# 0  Studying     Disgust      0
# 1  Studying     Dislike     10
# 2  Studying      Scared     15
# 3  Studying     Disgust      0
# 4  Studying  Interested     30
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/975...
# 2  https://socialbuzz.cdn.com/content/storage/975...
# 3  https://socialbuzz.cdn.com/content/storage/975...
# 4  https://socialbuzz.cdn.com/content/storage/975...

# %%
top_5 = df.groupby('Category')['Score'].sum().sort_values(ascending=False).head().reset_index()

top_5
# Out:
#          Category  Score
# 0          Travel  53935
# 1         Science  53657
# 2  Healthy Eating  52745
# 3         Animals  52443
# 4         Cooking  49681
